# %% [markdown]
# $\text{Project Introduction to Data Science with Python}$

# %% [markdown]
# $$\textbf{Disease Prediction Using Machine Learning}$$

# %%
from tabulate import tabulate
member_name = [
    ["LY Chhaythean", "Male", "I3-AMS", "e20220963"],
    ["LUN Rathana", "Female", "I3-AMS", "e20220368"],
    ["MIN Sivee", "Female", "I3-AMS", "e20220283"],
    ["LY Chhungheang", "Male", "I3-AMS", "e20220980"],
]
member_info = ["Name", "Gender", "Program", "ID"]
print("Group:")
print(tabulate(member_name, headers=member_info, tablefmt="fancy_grid"))
# Out:
# Group:
# ╒════════════════╤══════════╤═══════════╤═══════════╕
# │ Name           │ Gender   │ Program   │ ID        │
# ╞════════════════╪══════════╪═══════════╪═══════════╡
# │ LY Chhaythean  │ Male     │ I3-AMS    │ e20220963 │
# ├────────────────┼──────────┼───────────┼───────────┤
# │ LUN Rathana    │ Female   │ I3-AMS    │ e20220368 │
# ├────────────────┼──────────┼───────────┼───────────┤
# │ MIN Sivee      │ Female   │ I3-AMS    │ e20220283 │
# ├────────────────┼──────────┼───────────┼───────────┤
# │ LY Chhungheang │ Male     │ I3-AMS    │ e20220980 │
# ╘════════════════╧══════════╧═══════════╧═══════════╛

# %% [markdown]
# $\textbf{Import the libraries Pandas and Numpy}$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $\text{Read our Data Set}$

# %%
df = pd.read_csv("D:\My Project\Project Intro to DS\Project DS\Disease_Prediction\Dataset\dataset.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\chhay\AppData\Local\Temp\ipykernel_43404\3462270513.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("D:\My Project\Project Intro to DS\Project DS\Disease_Prediction\Dataset\dataset.csv")
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# $\textbf{Clean Up The Data}$

# %% [markdown]
# $\text{There are many nulls data here in our Data Set}$

# %% [markdown]
# $\text{The process of cleaning goes as belove show:}$

# %% [markdown]
# $1. \quad \text{Show the missing Data:}$

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %% [markdown]
# $\text{Summary Statistics}$

# %%
summary_stats = df.describe()
print(summary_stats)
# Out:
#                  Disease  Symptom_1  Symptom_2 Symptom_3    Symptom_4  \
# count               4920       4920       4920      4920         4572
# unique                41         34         48        54           50
# top     Fungal infection   vomiting   vomiting   fatigue   high_fever
# freq                 120        822        870       726          378
#
#         Symptom_5 Symptom_6        Symptom_7        Symptom_8  \
# count        3714      2934             2268             1944
# unique         38        32               26               21
# top      headache    nausea   abdominal_pain   abdominal_pain
# freq          348       390              264              276
#
#                  Symptom_9          Symptom_10     Symptom_11 Symptom_12  \
# count                 1692                1512           1194        744
# unique                  22                  21             18         11
# top      yellowing_of_eyes   yellowing_of_eyes   irritability    malaise
# ...

# %% [markdown]
# $\text{Count of Unique Values}$

# %%
unique_counts = df.nunique()
print(unique_counts)
# Out:
# Disease       41
# Symptom_1     34
# Symptom_2     48
# Symptom_3     54
# Symptom_4     50
# Symptom_5     38
# Symptom_6     32
# Symptom_7     26
# Symptom_8     21
# Symptom_9     22
# Symptom_10    21
# Symptom_11    18
# Symptom_12    11
# Symptom_13     8
# Symptom_14     4
# Symptom_15     3
# Symptom_16     3
# Symptom_17     1
# dtype: int64

# %% [markdown]
# $\textbf{Check if there are any missing value}$

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %% [markdown]
# $\textbf{More Advanced Descriptive Statistics}$

# %%
print(df.dtypes)
# Out:
# Disease       object
# Symptom_1     object
# Symptom_2     object
# Symptom_3     object
# Symptom_4     object
# Symptom_5     object
# Symptom_6     object
# Symptom_7     object
# Symptom_8     object
# Symptom_9     object
# Symptom_10    object
# Symptom_11    object
# Symptom_12    object
# Symptom_13    object
# Symptom_14    object
# Symptom_15    object
# Symptom_16    object
# Symptom_17    object
# dtype: object

# %%
# Select only numerical columns
numerical_df = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr()
print(correlation_matrix)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# $2. \quad \text{Deal with the null data:}$

# %%
df = df.fillna("")
df['Symptom'] = ""
for i in range(1,18):
    df['s'] = df['Symptom_{}'.format(i)]
    df['Symptom'] = df['Symptom'] + df['s']

# %% [markdown]
# $\textbf{ For the Null Value, We are going to fill it with nothing:}$

# %%
df.head(10)
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 5  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 6  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 7  Fungal infection     itching              skin_rash    dischromic _patches
# 8  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 9  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches
# 1
# 2
# ...

# %% [markdown]
# $\text{Merge all the columns together to pull all symptoms in one column, then we are going to use NLB technique to do the feature extraction}$

# %%
for i in range (1,18):
    df = df.drop("Symptom_{}".format(i), axis=1)

df = df.drop("s", axis=1)

# %%
df.head()
# Out:
#             Disease                                            Symptom
# 0  Fungal infection  itching skin_rash nodal_skin_eruptions dischro...
# 1  Fungal infection   skin_rash nodal_skin_eruptions dischromic _pa...
# 2  Fungal infection   itching nodal_skin_eruptions dischromic _patches
# 3  Fungal infection              itching skin_rash dischromic _patches
# 4  Fungal infection             itching skin_rash nodal_skin_eruptions

# %%
df[0:1].values
# Out:
# array([['Fungal infection',
#         'itching skin_rash nodal_skin_eruptions dischromic _patches']],
#       dtype=object)

# %%
df["Disease"].value_counts()
# Out:
# Disease
# Fungal infection                           120
# Allergy                                    120
# GERD                                       120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# AIDS                                       120
# Diabetes                                   120
# Gastroenteritis                            120
# Bronchial Asthma                           120
# Hypertension                               120
# Migraine                                   120
# Cervical spondylosis                       120
# Paralysis (brain hemorrhage)               120
# Jaundice                                   120
# Malaria                                    120
# Chicken pox                                120
# Dengue                                     120
# Typhoid                                    120
# hepatitis A                                120
# ...

# %% [markdown]
# $\text{All good since we have the Balance Data in there}$

# %%
x = df['Symptom']
y = df['Disease']

# %%
x.head(10)
# Out:
# 0    itching skin_rash nodal_skin_eruptions dischro...
# 1     skin_rash nodal_skin_eruptions dischromic _pa...
# 2     itching nodal_skin_eruptions dischromic _patches
# 3                itching skin_rash dischromic _patches
# 4               itching skin_rash nodal_skin_eruptions
# 5     skin_rash nodal_skin_eruptions dischromic _pa...
# 6     itching nodal_skin_eruptions dischromic _patches
# 7                itching skin_rash dischromic _patches
# 8               itching skin_rash nodal_skin_eruptions
# 9    itching skin_rash nodal_skin_eruptions dischro...
# Name: Symptom, dtype: object

# %%
y.head(10)
# Out:
# 0    Fungal infection
# 1    Fungal infection
# 2    Fungal infection
# 3    Fungal infection
# 4    Fungal infection
# 5    Fungal infection
# 6    Fungal infection
# 7    Fungal infection
# 8    Fungal infection
# 9    Fungal infection
# Name: Disease, dtype: object

# %% [markdown]
# $\text{Do the Descriptive Statistics and Visualize the Data}$

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.describe(include="all")
# Out:
#                  Disease                                            Symptom
# count               4920                                               4920
# unique                41                                                304
# top     Fungal infection   muscle_weakness stiff_neck swelling_joints mo...
# freq                 120                                                 90

# %%
plt.scatter(df['Symptom'], df['Disease'], color='red')
plt.xlabel('Symptom')
plt.ylabel('Disease')
plt.show()

# %%
disease_dist = df["Disease"].value_counts()

plt.figure(figsize=(12, 6))
plt.bar(disease_dist.index, disease_dist.values, color='skyblue')
plt.title('Disease Distribution')
plt.xlabel('Disease')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap

symptoms = []
for col in df.columns[1:]: 
    symptoms.extend(df[col].dropna().tolist())

symptom_counts = pd.Series(symptoms).value_counts()

symptom_counts = symptom_counts.sort_values(ascending=False)

symptom_counts = symptom_counts.head(20)  

symptom_counts.index = [textwrap.fill(symptom, width=20) for symptom in symptom_counts.index]

plt.figure(figsize=(12, 10)) 
sns.barplot(x=symptom_counts.values, y=symptom_counts.index, palette="viridis")
plt.title('Frequency of Symptoms Across All Diseases', fontsize=16)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Symptom', fontsize=14)


plt.yticks(rotation=0, fontsize=10)  

plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\chhay\AppData\Local\Temp\ipykernel_43404\1388921962.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=symptom_counts.values, y=symptom_counts.index, palette="viridis")

# %%
disease_counts = df['Disease'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(disease_counts, labels=disease_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title('Distribution of Diseases')
plt.show()

# %% [markdown]
# $\textbf{Machine Learning Process}$

# %% [markdown]
# $\text{We are going to split the data into two paths:}$

# %% [markdown]
# $1. \quad \text{Test Data}$

# %% [markdown]
# $2. \quad \text{Train Data}$

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=.25, shuffle=True, random_state=44)

# %%
print('Training Data Shape:', x_train.shape)
print('Testing Data Shape:', x_test.shape)
# Out:
# Training Data Shape: (3690,)
# Testing Data Shape: (1230,)

# %% [markdown]
# $\text{Now the most important part:}$

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

x_train_tfid = vectorizer.fit_transform(x_train)
x_train_tfid.shape
# Out:
# (3690, 135)

# %%
pd.DataFrame(x_train_tfid)[0]
# Out:
# 0       <Compressed Sparse Row sparse matrix of dtype ...
# 1       <Compressed Sparse Row sparse matrix of dtype ...
# 2       <Compressed Sparse Row sparse matrix of dtype ...
# 3       <Compressed Sparse Row sparse matrix of dtype ...
# 4       <Compressed Sparse Row sparse matrix of dtype ...
#                               ...
# 3685    <Compressed Sparse Row sparse matrix of dtype ...
# 3686    <Compressed Sparse Row sparse matrix of dtype ...
# 3687    <Compressed Sparse Row sparse matrix of dtype ...
# 3688    <Compressed Sparse Row sparse matrix of dtype ...
# 3689    <Compressed Sparse Row sparse matrix of dtype ...
# Name: 0, Length: 3690, dtype: object

# %% [markdown]
# $\text{Train the Model}$

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(x_train_tfid, y_train)
# Out:
# LinearSVC()

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', LinearSVC()),])

text_clf.fit(x_train, y_train)
predictions = text_clf.predict(x_test)

# %%
baseline_accuracy = 1 / len(np.unique(y_test))
print(f'Baseline Accuracy: {baseline_accuracy:.4f}')
# Out:
# Baseline Accuracy: 0.0244

# %%
from statsmodels.stats.contingency_tables import mcnemar

baseline_predictions = np.random.choice(y_test, size = len(y_test))

coningency_table = contingency_matrix(y_test, predictions)
print(coningency_table)

result = mcnemar(coningency_table, exact=True)
print(result)

alpha = 0.05

if result.pvalue < alpha:
    print('Reject the null hypothesis:The model performs significantly better than the baseline.')
else:
    print('Fail to reject the null hypothesis: The model does not perform significantly better than the baseline.')

# %% [markdown]
# $\text{Display the Accuracy}$

# %%
from sklearn import metrics
print(metrics.confusion_matrix(y_test, predictions))
# Out:
# [[33  0  0 ...  0  0  0]
#  [ 0 33  0 ...  0  0  0]
#  [ 0  0 35 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 31  0  0]
#  [ 0  0  0 ...  0 31  0]
#  [ 0  0  0 ...  0  0 25]]

# %%
print(metrics.classification_report(y_test, predictions))
# Out:
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00        33
#                                    AIDS       1.00      1.00      1.00        33
#                                    Acne       1.00      1.00      1.00        35
#                     Alcoholic hepatitis       1.00      1.00      1.00        33
#                                 Allergy       1.00      1.00      1.00        25
#                               Arthritis       1.00      1.00      1.00        29
#                        Bronchial Asthma       1.00      1.00      1.00        30
#                    Cervical spondylosis       1.00      1.00      1.00        35
#                             Chicken pox       1.00      1.00      1.00        35
#                     Chronic cholestasis       1.00      1.00      1.00        31
#                             Common Cold       1.00      1.00      1.00        29
# ...

# %%
print(metrics.accuracy_score(y_test, predictions))
# Out:
# 1.0

# %% [markdown]
# $\textbf{The Accuracy:}$ $100 \%$

# %% [markdown]
# $\textbf{GradientBoostingClassifier}$

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn import metrics

text_clf = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', GradientBoostingClassifier(n_estimators=100, random_state=44)),
])

# Train the model
text_clf.fit(x_train, y_train)

# Make predictions
predictions = text_clf.predict(x_test)

# Calculate accuracy
accuracy = metrics.accuracy_score(y_test, predictions)

# %%
# Confusion Matrix
print("Confusion Matrix:")
print(metrics.confusion_matrix(y_test, predictions))

# Classification Report
print("Classification Report:")
print(metrics.classification_report(y_test, predictions))

# Accuracy Score
print("Accuracy Score:")
print(metrics.accuracy_score(y_test, predictions))
# Out:
# Confusion Matrix:
# [[33  0  0 ...  0  0  0]
#  [ 0 33  0 ...  0  0  0]
#  [ 0  0 35 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 31  0  0]
#  [ 0  0  0 ...  0 31  0]
#  [ 0  0  0 ...  0  0 25]]
# Classification Report:
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00        33
#                                    AIDS       1.00      1.00      1.00        33
#                                    Acne       1.00      1.00      1.00        35
#                     Alcoholic hepatitis       1.00      1.00      1.00        33
#                                 Allergy       1.00      1.00      1.00        25
#                               Arthritis       1.00      1.00      1.00        29
#                        Bronchial Asthma       1.00      1.00      1.00        30
#                    Cervical spondylosis       1.00      1.00      1.00        35
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, auc
import pandas as pd

# Plot Confusion Matrix
plt.figure(figsize=(10, 7))
ConfusionMatrixDisplay.from_estimator(text_clf, x_test, y_test, cmap=plt.cm.Blues, normalize='true')
plt.title('Confusion Matrix')
plt.show()

# Plot Feature Importances
if hasattr(text_clf.named_steps['clf'], 'feature_importances_'):
    feature_importances = text_clf.named_steps['clf'].feature_importances_
elif hasattr(text_clf.named_steps['clf'], 'coef_'):
    feature_importances = text_clf.named_steps['clf'].coef_[0]
else:
    raise AttributeError("The classifier does not have feature_importances_ or coef_ attribute.")

features = text_clf.named_steps['tfidf'].get_feature_names_out()
importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False).head(20)  # Top 20 features

plt.figure(figsize=(10, 7))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Top 20 Feature Importances')
plt.show()

# Plot ROC Curve
if hasattr(text_clf, 'predict_proba'):
    y_prob = text_clf.predict_proba(x_test)[:, 1]
else:
    y_prob = text_clf.decision_function(x_test)  # For models like SVC without probability estimation

fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label=text_clf.classes_[1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 7))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
ds = pd.read_csv("D:\My Project\Project Intro to DS\Project DS\Disease_Prediction\Dataset\symptom_Description.csv")
ds.head(43)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\chhay\AppData\Local\Temp\ipykernel_43404\20296419.py:1: SyntaxWarning: invalid escape sequence '\M'
#   ds = pd.read_csv("D:\My Project\Project Intro to DS\Project DS\Disease_Prediction\Dataset\symptom_Description.csv")
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# ...

# %%
ds.isnull().sum()
# Out:
# Disease        0
# Description    0
# dtype: int64

# %%
ds.index = ds['Disease']
ds = ds.drop('Disease', axis=1)
ds.head(43)
# Out:
#                                                                                Description
# Disease
# Drug Reaction                            An adverse drug reaction (ADR) is an injury ca...
# Malaria                                  An infectious disease caused by protozoan para...
# Allergy                                  An allergy is an immune system response to a f...
# Hypothyroidism                           Hypothyroidism, also called underactive thyroi...
# Psoriasis                                Psoriasis is a common skin disorder that forms...
# GERD                                     Gastroesophageal reflux disease, or GERD, is a...
# Chronic cholestasis                      Chronic cholestatic diseases, whether occurrin...
# hepatitis A                              Hepatitis A is a highly contagious liver infec...
# Osteoarthristis                          Osteoarthritis is the most common form of arth...
# ...

# %%
pr = pd.read_csv("D:\My Project\Project Intro to DS\Project DS\Disease_Prediction\Dataset\symptom_precaution.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\chhay\AppData\Local\Temp\ipykernel_43404\315803493.py:1: SyntaxWarning: invalid escape sequence '\M'
#   pr = pd.read_csv("D:\My Project\Project Intro to DS\Project DS\Disease_Prediction\Dataset\symptom_precaution.csv")

# %%
pr.isnull().sum()
# Out:
# Disease         0
# Precaution_1    0
# Precaution_2    0
# Precaution_3    1
# Precaution_4    1
# dtype: int64

# %%
pr = pr.fillna("")
pr.head(43)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
pd.DataFrame(pr)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
pr['precautions']=""
pr['punc']=', '
for i in range(1,5):
    pr['s']=pr["Precaution_{}".format(i)]+pr['punc']
    pr['precautions']=pr['precautions']+pr['s']
pr.head(43)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
for i in range(1, 5):
    pr = pr.drop("Precaution_{}".format(i), axis=1)

pr.head(43)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
pr = pr.drop(['s', 'punc'], axis=1)
pr.head(43)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
s = input('Please choose your symptoms (e.g., "itching skin_rash nodal_skin_eruptions"): ')

disease_of_patient = text_clf.predict([s])[0]

discription = ds['Description'][disease_of_patient]

if disease_of_patient in pr['precautions']:
    precaution = pr['precautions'][disease_of_patient]
else:
    precaution = 'Precautions not available for this disease.'

# Display the results
print(f'\nYou have {disease_of_patient}\n\nDescription: {discription}\n\nYou should {precaution}')
# Out:
# You have Chronic cholestasis
#
# Description: Chronic cholestatic diseases, whether occurring in infancy, childhood or adulthood, are characterized by defective bile acid transport from the liver to the intestine, which is caused by primary damage to the biliary epithelium in most cases
#
# You should Precautions not available for this disease.
